# %%
import pandas as pd
import numpy as np
from itertools import islice
import re

# %%
pattern = re.compile(r"((?!\|)(b\\|(\w+|\.|\s)+)|(?=\|))")

# %%
with open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt") as myfile:
    head = list(islice(myfile, 0,4))
    print(pattern.findall(head))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-12b1a2abee95> in <module>()
#       1 with open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt") as myfile:
#       2     head = list(islice(myfile, 0,4))
# ----> 3     print(pattern.findall(head))
#
# TypeError: expected string or bytes-like object

# %%
#Works on file 3 and file 1

f = open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt", 'r')
currentline = ""
linelist = []
for line in f:
    if line.startswith('|'):
        currentline = line
        next
    elif line.startswith(' '):
        fullline = currentline.strip('\n') + line.strip('\n')
        linelist.append(fullline.strip('\n').strip('-').split('|'))
        currentline = ""
        fullline = ""
        next
    else:
        next

f.close()

with open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt") as myfile:
    head = list(islice(myfile, 2,4))

header = head[0].strip('\n') + head[1].strip('\n')
header = header.split('|')
header.pop(0)

df = pd.DataFrame(linelist)
df = df.drop([0,69], axis=1)
df.columns = header

# %%
f = open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\example_2.txt", 'r')
currentline = ""
linelist = []
for line in f:
    if line.startswith('|'):
        currentline = line
        next
        
    else:
        fullline = currentline.strip('\n') + line.strip('\n')
        linelist.append(fullline.strip('\n').strip('-').split('|'))
        currentline = ""
        fullline = ""
        next

f.close()

with open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt") as myfile:
    head = list(islice(myfile, 2,4))

header = head[0].strip('\n') + head[1].strip('\n')
header = header.split('|')
header.pop(0)

df = pd.DataFrame(linelist)
#df = df.drop([0,69], axis=1)
#df.columns = header

# %%
f = open(r"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\example_2.txt", 'r')
for line in f:
    append line
f.close()

# %%
lines
# Out:
# ['11/08/2018                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Dynamic List Display                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\n',
#  '  Cl.',
#  'CoCd',
#  'DocumentNo',
#  'Year',
#  'Doc. Type',
#  'Doc. Date ',
#  'Pstng Date',
#  'Period',
#  'Entry Dte ',
#  'Time    ',
#  'Changed   ',
#  'Last updte',
#  'TranslDate',
#  'User name',
#  'TCode',
#  'Cross-CC number ',
#  'Reference      ',
#  'RecEnt doc',
#  'Rev. with',
#  'Year',
#  'Document Header Text',
#  'Crcy',
#  'Exch.rate',
#  'GrpCy',
#  'Group exchange rate',
#  'S',
#  'XNETB',
#  'Un.del.cts',
#  'I',
#  'Tran',
#  'Sess. Name',
#  'Document name in the archive system',
#  'ExtractID',
#  'DT',
#  'Ref. Tran.',
#  'Ref. Key          ',
#  'FMA',
#  'LCurr',
#  'LCur2',
#  'LCur3',
#  'Ex.rate 2',
#  'Ex.rate 3',
#  'SC',
#  'SC',
#  'Tr.date',
#  'Tr.date',
#  'XSTOV',
#  'Reversal date',
#  'Calc.tax',
#  'CT',
#  'CT',
#  'ERTy',
#  'ERTy',
#  'Net entry',
#  'SCCd',
#  'Tax detail',
#  'Status of Data Transfer to Next Release',
#  'Log.System',
#  'Rte txs',
#  'TaxRate:LC',
#  'Request No',
#  'Customer bill/exch. paid before due date',
#  'Reason',
#  'Parked by',
#  'Branch number',
#  'Pages',
#  'dis. doc.',
#  'Ref.key 1',
#  'Ref.key 2',
#  'Reversal',
#  'IR date   ',
#  'Ld',
#  'Ledger Group',
#  'Mand.',
#  'Alt Refer Number',
#  'Rep. Date ',
#  'Doc.Type',
#  'Split',
#  'Cash Flow-Relevant Doc.',
#  'Follow-on document indicator',
#  'Reorg',
#  'Subs',
#  'ERTy',
#  'Market Data Exchange Rate',
#  'Market Data Exchange Rate 2',
#  'Market Data Exchange Rate 3',
#  'Document Originates from Multi Currency',
#  'Resubmission Date',
#  'Document Status',
#  'RT',
#  'Reason',
#  'Region\n',
#  'S',
#  'File number',
#  'IF',
#  'Int.rt.dte',
#  'Posting Day',
#  'Act',
#  'Chngd on\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\n',
#  '  300',
#  '0011',
#  '600000115 ',
#  '2018',
#  'ZF       ',
#  '12/13/2017',
#  '01/01/2018',
#  '     1',
#  '01/12/2018',
#  '10:04:01',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'MQS657   ',
#  'FBVB ',
#  '0600000115001118',
#  '10075337       ',
#  '          ',
#  '         ',
#  '    ',
#  'ZJEM8               ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060022016800112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000116 ',
#  '2018',
#  'ZF       ',
#  '12/18/2017',
#  '01/01/2018',
#  '     1',
#  '01/10/2018',
#  '12:04:17',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'QZR557   ',
#  'FBVB ',
#  '                ',
#  '1712522        ',
#  '          ',
#  '         ',
#  '    ',
#  'QZR557              ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060023351200112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000119 ',
#  '2018',
#  'ZF       ',
#  '12/01/2017',
#  '01/01/2018',
#  '     1',
#  '01/10/2018',
#  '12:03:48',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'QZR557   ',
#  'FBVB ',
#  '                ',
#  '1712488        ',
#  '          ',
#  '         ',
#  '    ',
#  'QZR557              ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060021834300112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000120 ',
#  '2018',
#  'ZF       ',
#  '12/04/2017',
#  '01/01/2018',
#  '     1',
#  '01/05/2018',
#  '11:25:56',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'ZARM5    ',
#  'FBVB ',
#  '0600000120001118',
#  'R0052546       ',
#  '          ',
#  '         ',
#  '    ',
#  'ZARM5               ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060021065500112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000121 ',
#  '2018',
#  'ZG       ',
#  '12/07/2017',
#  '01/01/2018',
#  '     1',
#  '12/20/2017',
#  '18:18:52',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'WF-BATCH ',
#  'FV60 ',
#  '                ',
#  '110052         ',
#  '          ',
#  '         ',
#  '    ',
#  'ZKMD2               ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  'Z',
#  '     ',
#  '     0.00 ',
#  ' ',
#  '    ',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060021917600112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '0011',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  '         ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  '    ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000122 ',
#  '2018',
#  'ZG       ',
#  '11/13/2017',
#  '01/01/2018',
#  '     1',
#  '01/18/2018',
#  '14:15:17',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'FFG168   ',
#  'FBVB ',
#  '0600000122001118',
#  '108843         ',
#  '          ',
#  '         ',
#  '    ',
#  'FFG168              ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060021402700112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  '  300',
#  '0011',
#  '600000123 ',
#  '2018',
#  'ZG       ',
#  '07/13/2017',
#  '01/01/2018',
#  '     1',
#  '01/03/2018',
#  '09:55:08',
#  '          ',
#  '          ',
#  '01/01/2018',
#  'PPK824   ',
#  'FBVB ',
#  '0600000123001118',
#  '106666         ',
#  '          ',
#  '         ',
#  '    ',
#  'PPK824              ',
#  'USD ',
#  '         ',
#  '     ',
#  '                   ',
#  ' ',
#  '     ',
#  '     0.00 ',
#  ' ',
#  'RFBU',
#  '          ',
#  '                                   ',
#  '         ',
#  '  ',
#  'BKPF      ',
#  '060022580700112017',
#  '   ',
#  'USD  ',
#  'USD  ',
#  '     ',
#  '         ',
#  '         ',
#  '2 ',
#  '  ',
#  '3      ',
#  '       ',
#  '     ',
#  '             ',
#  '        ',
#  '30',
#  '  ',
#  'M   ',
#  '    ',
#  '         ',
#  '    ',
#  '          ',
#  '                                       ',
#  '          ',
#  '       ',
#  '          ',
#  '          ',
#  '                                        ',
#  '      ',
#  'WF-BATCH ',
#  '             ',
#  '     ',
#  '         ',
#  '         ',
#  '         ',
#  '        ',
#  '          ',
#  '  ',
#  '            ',
#  '     ',
#  '                ',
#  '          ',
#  '        ',
#  '     ',
#  '                       ',
#  '                            ',
#  '     ',
#  '    ',
#  'M   ',
#  '                         ',
#  '                           ',
#  '                           ',
#  '                                       ',
#  '                 ',
#  '               ',
#  '  ',
#  '      ',
#  '\n',
#  ' ',
#  '           ',
#  '  ',
#  '          ',
#  '           ',
#  '   ',
#  '          ',
#  '\n',
#  ...]

# %%
df = df[df.CoCd != "Table"]
df = df[df.CoCd != "Number"]
df = df[df.CoCd != "Maximum"]
df = df[df.CoCd != "Runtime"]
df = df[df.CoCd != "CoCd"]

# %%
df.columns = ['CoCd', 'DocumentNo', 'Year', 'Type', 'Doc.Date', 'Pstng Date', 'Period', 'Year',' ', '']

# %%
df7 = df[df.Period == "7"]
df8 = df[df.Period == "8"]
df9 = df[df.Period == "9"]

# %%
np.max(df.DocumentNo)
# Out:
# '600197200'

# %%
print(df7['DocumentNo'].nunique())
print(df8['DocumentNo'].nunique())
print(df9['DocumentNo'].nunique())
# Out:
# 288756
# 256944
# 223981

# %%
no1 = df7['DocumentNo'].nunique()
no2 = df8['DocumentNo'].nunique()
no3 = df9['DocumentNo'].nunique()

# %%
sum([no1,no2,no3])
# Out:
# 769681

# %%
DN, count = np.unique(df.DocumentNo, return_counts=True)

# %%
d2 = pd.DataFrame({'x': DN, 'Y':count})

# %%
d2.sort_values('Y', ascending=False)
# Out:
#                 x   Y
# 100     100000200  19
# 1437    100002800  17
# 1548    100003000  16
# 147     100000300  15
# 171     100000400  15
# 1575    100003100  15
# 1521    100002900  15
# 251     100000600  14
