# %%
import pandas as pd
import numpy as np
from itertools import islice
import re

# %%
#C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_1.txt PASSED
#"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\example_2.txt"
#"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_2.txt" PASSED
#"C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\file_3.txt PASSED"
file = input('Please Provide FilePath:')
# Out:
# Please Provide FilePath:C:\Users\hwe334\OneDrive - Anadarko\Python Scripts\data\headerwrap\example_2.txt

# %%
try:
    df = pd.read_table(
        file,
        delimiter="|",
        skiprows=[0, 1, 3],
        na_filter=True,
        engine='python',
        skipfooter=1).dropna(
            axis=1, how='all')
    check = df.isnull().values.any()
except:
    check = True

# %%
check
# Out:
# True

# %%
if check == True:
    pattern = re.compile(r"((?!\|).*?(?=\|))")

    with open(file, 'r') as f:
        content = f.readlines()

    lines = []
    for x in content:
        if not x.startswith("--"):
            l = x.strip('\n')
            lines.append(l)
            
       


    data = []
    count = 0
    lenlist = []

    for x in lines[3:]:
        l = pattern.findall(x)
        if len(l) > 2 and count == 0:
            data.append(l)
            lenlist.append(len(l))
            count += 1
        elif len(l) > 2 and count == 1:
            data[-1].extend(l)
            lenlist.append(len(l))
            count -= 1
        else:
            count = 0
            next

# %%
lines = []
for x in content:
    if not x.startswith("--"):
        l = x.replace("\n","|")
        lines.append(l)

pattern = re.compile(r"")
count = 0
header = []

for x in lines[:3]:
    
    l = pattern.findall(x)
    if len(l) > 2 and count == 0:
        header.append(l)
        count += 1
    elif len(l) > 2 and count == 1:
        header[-1].extend(l)
        count -= 1
    else:
        count = 0
        next

# %%
for x in data:
    print(len(x))
# Out:
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# ...

# %%
lines
# Out:
# ['11/08/2018                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Dynamic List Display                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
df = pd.DataFrame(data[1:])
#df = df[df[df.columns[0]] != df.columns[0]]

df
# Out:
#         0     1           2     3          4           5           6       7   \
# 0      300  0011  600000116   2018  ZF         12/18/2017  01/01/2018       1
# 1      300  0011  600000117   2018  ZF         12/18/2017  01/01/2018       1
# 2      300  0011  600000118   2018  ZF         12/18/2017  01/01/2018       1
# 3      300  0011  600000119   2018  ZF         12/01/2017  01/01/2018       1
# 4      300  0011  600000120   2018  ZF         12/04/2017  01/01/2018       1
# 5      300  0011  600000121   2018  ZG         12/07/2017  01/01/2018       1
# 6      300  0011  600000122   2018  ZG         11/13/2017  01/01/2018       1
# 7      300  0011  600000123   2018  ZG         07/13/2017  01/01/2018       1
# 8      300  0011  600000124   2018  ZG         12/15/2017  01/01/2018       1
# 9      300  0011  600000125   2018  ZG         12/18/2017  01/01/2018       1
# 10     300  0011  600000126   2018  ZG         07/31/2017  01/01/2018       1
# ...

# %%
# Out:
# 'AFE Description   '
